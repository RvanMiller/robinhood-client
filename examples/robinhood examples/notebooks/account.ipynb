# %% [markdown]
# # Reading Account Info

# %% [markdown]
# Log in using existing session with `pk.login()`.  To log in for the first time, use PYOTP and `pk.login(...)`.

# %%
import parakeet as pk

pk.login()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 import parakeet as pk
# ----> 3 pk.login()
#
# AttributeError: module 'parakeet' has no attribute 'login'

# %%
pk.get_interest_payments()
# Out:
# [{'amount': {'amount': '221.47',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '85c57cab-f5d9-4d78-920e-ca00c05b0ef6',
#   'account_number': '5PY28264',
#   'pay_date': '2025-07-31T21:00:00Z',
#   'pay_period_start': '2025-07-31T21:00:00Z',
#   'pay_period_end': '2025-07-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '25.80',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '3f605e25-e5c4-4cbd-b341-e5853c3b567c',
#   'account_number': '5PY28264',
#   'pay_date': '2025-06-30T21:00:00Z',
#   'pay_period_start': '2025-06-30T21:00:00Z',
#   'pay_period_end': '2025-06-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '153.00',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'ff261210-db98-4e03-ae45-67ab845e9340',
#   'account_number': '5PY28264',
#   'pay_date': '2025-05-30T21:00:00Z',
#   'pay_period_start': '2025-05-30T21:00:00Z',
#   'pay_period_end': '2025-05-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '41.33',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '013b10a3-a2d5-47a4-ad82-1908ca48b244',
#   'account_number': '5PY28264',
#   'pay_date': '2025-04-30T21:00:00Z',
#   'pay_period_start': '2025-04-30T21:00:00Z',
#   'pay_period_end': '2025-04-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '388.65',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '104a35ba-0ca9-4702-afa1-0de4cbe47a8c',
#   'account_number': '5PY28264',
#   'pay_date': '2025-04-25T21:00:00Z',
#   'pay_period_start': '2025-04-25T21:00:00Z',
#   'pay_period_end': '2025-04-25T21:00:00Z',
#   'payout_type': 'unidentified_early_interest_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '611.36',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '7ff4cf67-3928-4a3e-a67a-3ad4f53ca647',
#   'account_number': '5PY28264',
#   'pay_date': '2025-03-31T21:00:00Z',
#   'pay_period_start': '2025-03-31T21:00:00Z',
#   'pay_period_end': '2025-03-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '576.79',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'c0d5c8f5-ee8c-4383-ac82-362bd9f71603',
#   'account_number': '5PY28264',
#   'pay_date': '2025-02-28T22:00:00Z',
#   'pay_period_start': '2025-02-28T22:00:00Z',
#   'pay_period_end': '2025-02-28T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '636.47',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '8ad39f0a-7715-4710-a577-d74ebf023c7a',
#   'account_number': '5PY28264',
#   'pay_date': '2025-01-31T22:00:00Z',
#   'pay_period_start': '2025-01-31T22:00:00Z',
#   'pay_period_end': '2025-01-31T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '591.54',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '0229d08e-12b0-409e-876e-e81a7e567e9c',
#   'account_number': '5PY28264',
#   'pay_date': '2024-12-31T22:00:00Z',
#   'pay_period_start': '2024-12-31T22:00:00Z',
#   'pay_period_end': '2024-12-31T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '441.27',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'd410b685-ef67-4683-a003-856a80c7930f',
#   'account_number': '5PY28264',
#   'pay_date': '2024-11-29T22:00:00Z',
#   'pay_period_start': '2024-11-29T22:00:00Z',
#   'pay_period_end': '2024-11-29T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '154.37',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'c2205d78-1c1e-4bbb-b4dd-51b6a1eca5c4',
#   'account_number': '5PY28264',
#   'pay_date': '2024-10-31T21:00:00Z',
#   'pay_period_start': '2024-10-31T21:00:00Z',
#   'pay_period_end': '2024-10-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '277.89',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '1ecdd3f7-30b2-4c62-9e68-7b3b28495364',
#   'account_number': '5PY28264',
#   'pay_date': '2024-09-30T21:00:00Z',
#   'pay_period_start': '2024-09-30T21:00:00Z',
#   'pay_period_end': '2024-09-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '138.52',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '485aeb57-dc11-444a-986c-3326f6f45aec',
#   'account_number': '5PY28264',
#   'pay_date': '2024-08-30T21:00:00Z',
#   'pay_period_start': '2024-08-30T21:00:00Z',
#   'pay_period_end': '2024-08-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '166.38',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'bd6266a3-8c3f-4a5d-a74a-b7d175c1564d',
#   'account_number': '5PY28264',
#   'pay_date': '2024-08-20T21:00:00Z',
#   'pay_period_start': '2024-08-20T21:00:00Z',
#   'pay_period_end': '2024-08-20T21:00:00Z',
#   'payout_type': 'unidentified_early_interest_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '126.94',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'fff4df0d-d305-4a98-8a95-ad4a0e2bab4d',
#   'account_number': '5PY28264',
#   'pay_date': '2024-07-31T21:00:00Z',
#   'pay_period_start': '2024-07-31T21:00:00Z',
#   'pay_period_end': '2024-07-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '190.28',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '446b1b1d-d5a7-461d-b88a-93f2cdb75eb1',
#   'account_number': '5PY28264',
#   'pay_date': '2024-07-16T21:00:00Z',
#   'pay_period_start': '2024-07-16T21:00:00Z',
#   'pay_period_end': '2024-07-16T21:00:00Z',
#   'payout_type': 'unidentified_early_interest_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '65.56',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '03e6bbee-cd27-404c-9083-fe25e5b2085d',
#   'account_number': '5PY28264',
#   'pay_date': '2024-06-28T21:00:00Z',
#   'pay_period_start': '2024-06-28T21:00:00Z',
#   'pay_period_end': '2024-06-28T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '198.91',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '4d10cb24-a140-40e8-aea5-9c031d81584d',
#   'account_number': '5PY28264',
#   'pay_date': '2024-06-26T21:00:00Z',
#   'pay_period_start': '2024-06-26T21:00:00Z',
#   'pay_period_end': '2024-06-26T21:00:00Z',
#   'payout_type': 'unidentified_early_interest_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '145.62',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '21d995ef-5a98-428a-a44e-ea668df9cdf7',
#   'account_number': '5PY28264',
#   'pay_date': '2024-05-31T21:00:00Z',
#   'pay_period_start': '2024-05-31T21:00:00Z',
#   'pay_period_end': '2024-05-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '136.24',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '3ac63472-bf3c-4491-8fc4-f01e85800e39',
#   'account_number': '5PY28264',
#   'pay_date': '2024-04-30T21:00:00Z',
#   'pay_period_start': '2024-04-30T21:00:00Z',
#   'pay_period_end': '2024-04-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '72.87',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '0ef43db0-dd5e-42fa-a32b-a589125d5825',
#   'account_number': '5PY28264',
#   'pay_date': '2024-03-28T21:00:00Z',
#   'pay_period_start': '2024-03-28T21:00:00Z',
#   'pay_period_end': '2024-03-28T21:00:00Z',
#   'payout_type': 'unidentified_early_interest_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '99.20',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'da0c6090-574e-4947-8b1c-1893a9f5755c',
#   'account_number': '5PY28264',
#   'pay_date': '2024-02-29T22:00:00Z',
#   'pay_period_start': '2024-02-29T22:00:00Z',
#   'pay_period_end': '2024-02-29T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '93.27',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'e4755148-d59b-4b19-a7c4-ca13bfc7f99a',
#   'account_number': '5PY28264',
#   'pay_date': '2024-01-31T22:00:00Z',
#   'pay_period_start': '2024-01-31T22:00:00Z',
#   'pay_period_end': '2024-01-31T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '91.83',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'ae184f24-1a4c-4fd2-8a9e-16ac1c6c4fed',
#   'account_number': '5PY28264',
#   'pay_date': '2023-12-29T22:00:00Z',
#   'pay_period_start': '2023-12-29T22:00:00Z',
#   'pay_period_end': '2023-12-29T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '87.53',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'a3c956aa-32a3-4688-af92-35dbb9253b07',
#   'account_number': '5PY28264',
#   'pay_date': '2023-11-30T22:00:00Z',
#   'pay_period_start': '2023-11-30T22:00:00Z',
#   'pay_period_end': '2023-11-30T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '89.15',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '1b7a6f0c-3ea7-4dd8-856e-1bea12730d05',
#   'account_number': '5PY28264',
#   'pay_date': '2023-10-31T21:00:00Z',
#   'pay_period_start': '2023-10-31T21:00:00Z',
#   'pay_period_end': '2023-10-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '54.49',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '91557341-05dc-4882-9a04-1aec35104656',
#   'account_number': '5PY28264',
#   'pay_date': '2023-09-29T21:00:00Z',
#   'pay_period_start': '2023-09-29T21:00:00Z',
#   'pay_period_end': '2023-09-29T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '13.33',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '2c1d55e4-3806-4fbd-8a79-e26d8b3c0441',
#   'account_number': '5PY28264',
#   'pay_date': '2023-08-31T21:00:00Z',
#   'pay_period_start': '2023-08-31T21:00:00Z',
#   'pay_period_end': '2023-08-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '127.36',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'e79e6192-8cfb-4d1c-a253-9098d7449104',
#   'account_number': '5PY28264',
#   'pay_date': '2023-07-31T21:00:00Z',
#   'pay_period_start': '2023-07-31T21:00:00Z',
#   'pay_period_end': '2023-07-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '28.23',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '3805f5cc-504a-4e8b-9ba6-9a5643de301e',
#   'account_number': '5PY28264',
#   'pay_date': '2023-06-30T21:00:00Z',
#   'pay_period_start': '2023-06-30T21:00:00Z',
#   'pay_period_end': '2023-06-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '35.70',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'f03cb829-859a-427d-98e8-9f4f7d004d24',
#   'account_number': '5PY28264',
#   'pay_date': '2023-06-23T21:00:00Z',
#   'pay_period_start': '2023-06-23T21:00:00Z',
#   'pay_period_end': '2023-06-23T21:00:00Z',
#   'payout_type': 'unidentified_early_interest_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '54.72',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'a865b017-6bd8-4f8f-8633-1711a066974e',
#   'account_number': '5PY28264',
#   'pay_date': '2023-05-31T21:00:00Z',
#   'pay_period_start': '2023-05-31T21:00:00Z',
#   'pay_period_end': '2023-05-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '64.59',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '819f6744-53ec-4ace-8eee-0ae8b815d285',
#   'account_number': '5PY28264',
#   'pay_date': '2023-04-28T21:00:00Z',
#   'pay_period_start': '2023-04-28T21:00:00Z',
#   'pay_period_end': '2023-04-28T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '46.73',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '41a52aad-830e-4ac3-af76-d012f0d13cd9',
#   'account_number': '5PY28264',
#   'pay_date': '2023-03-31T21:00:00Z',
#   'pay_period_start': '2023-03-31T21:00:00Z',
#   'pay_period_end': '2023-03-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '23.65',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '996808e1-996b-4997-88be-86f0fca6e4b6',
#   'account_number': '5PY28264',
#   'pay_date': '2023-02-28T22:00:00Z',
#   'pay_period_start': '2023-02-28T22:00:00Z',
#   'pay_period_end': '2023-02-28T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '5.46',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'f88faceb-6e82-4ce8-abe5-6c132df64cba',
#   'account_number': '5PY28264',
#   'pay_date': '2023-01-31T22:00:00Z',
#   'pay_period_start': '2023-01-31T22:00:00Z',
#   'pay_period_end': '2023-01-31T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '2.86',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '099f7de2-fd19-418c-a59a-cdc40bbfb8c9',
#   'account_number': '5PY28264',
#   'pay_date': '2022-12-30T22:00:00Z',
#   'pay_period_start': '2022-12-30T22:00:00Z',
#   'pay_period_end': '2022-12-30T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '2.83',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '5d5211c6-a53f-46d7-872f-93ae599693a3',
#   'account_number': '5PY28264',
#   'pay_date': '2022-11-30T22:00:00Z',
#   'pay_period_start': '2022-11-30T22:00:00Z',
#   'pay_period_end': '2022-11-30T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '2.17',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '36c45c3c-28c2-4c6a-9b2d-78c1a26ea1be',
#   'account_number': '5PY28264',
#   'pay_date': '2022-10-31T21:00:00Z',
#   'pay_period_start': '2022-10-31T21:00:00Z',
#   'pay_period_end': '2022-10-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.23',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '107a6eff-e133-4a3a-a768-512e099e3cc7',
#   'account_number': '5PY28264',
#   'pay_date': '2022-09-30T21:00:00Z',
#   'pay_period_start': '2022-09-30T21:00:00Z',
#   'pay_period_end': '2022-09-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.46',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '699bde85-9daf-43ec-ad45-30d2fb1c31d5',
#   'account_number': '5PY28264',
#   'pay_date': '2022-08-31T21:00:00Z',
#   'pay_period_start': '2022-08-31T21:00:00Z',
#   'pay_period_end': '2022-08-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.65',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '3c22e1f2-ca29-463e-9f20-27cf760b5614',
#   'account_number': '5PY28264',
#   'pay_date': '2022-07-29T21:00:00Z',
#   'pay_period_start': '2022-07-29T21:00:00Z',
#   'pay_period_end': '2022-07-29T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.62',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '13e79308-aba5-40dc-a671-fbe220154acb',
#   'account_number': '5PY28264',
#   'pay_date': '2022-06-30T21:00:00Z',
#   'pay_period_start': '2022-06-30T21:00:00Z',
#   'pay_period_end': '2022-06-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.78',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '23a1b396-df68-4dff-8e51-64e209861f48',
#   'account_number': '5PY28264',
#   'pay_date': '2022-05-31T21:00:00Z',
#   'pay_period_start': '2022-05-31T21:00:00Z',
#   'pay_period_end': '2022-05-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '1.03',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'ad697c41-480f-4b52-9433-aa756f6774ac',
#   'account_number': '5PY28264',
#   'pay_date': '2022-04-29T21:00:00Z',
#   'pay_period_start': '2022-04-29T21:00:00Z',
#   'pay_period_end': '2022-04-29T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.17',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'fda252d7-1e78-4969-92b8-fa5c71a81265',
#   'account_number': '5PY28264',
#   'pay_date': '2022-03-31T21:00:00Z',
#   'pay_period_start': '2022-03-31T21:00:00Z',
#   'pay_period_end': '2022-03-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.07',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'd1009faa-59ce-408e-b683-07c5494545b3',
#   'account_number': '5PY28264',
#   'pay_date': '2022-02-28T22:00:00Z',
#   'pay_period_start': '2022-02-28T22:00:00Z',
#   'pay_period_end': '2022-02-28T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.08',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '876736ae-bed4-4777-9152-70e77ac6d23d',
#   'account_number': '5PY28264',
#   'pay_date': '2022-01-31T22:00:00Z',
#   'pay_period_start': '2022-01-31T22:00:00Z',
#   'pay_period_end': '2022-01-31T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.08',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '7bf8a23d-c231-43a6-a05e-d0a1945b5721',
#   'account_number': '5PY28264',
#   'pay_date': '2021-12-31T22:00:00Z',
#   'pay_period_start': '2021-12-31T22:00:00Z',
#   'pay_period_end': '2021-12-31T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.52',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '647a68fa-988e-4ab0-b7b4-7c481a96ae03',
#   'account_number': '5PY28264',
#   'pay_date': '2021-11-30T22:00:00Z',
#   'pay_period_start': '2021-11-30T22:00:00Z',
#   'pay_period_end': '2021-11-30T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '1.20',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '32dbae28-4a41-467e-b287-143335be0858',
#   'account_number': '5PY28264',
#   'pay_date': '2021-10-29T21:00:00Z',
#   'pay_period_start': '2021-10-29T21:00:00Z',
#   'pay_period_end': '2021-10-29T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '1.17',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '65f38980-70b9-40b2-9e93-06ab6aa29bdb',
#   'account_number': '5PY28264',
#   'pay_date': '2021-09-30T21:00:00Z',
#   'pay_period_start': '2021-09-30T21:00:00Z',
#   'pay_period_end': '2021-09-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.65',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'eb7075aa-55ec-4e67-afcf-bc2067c21e6c',
#   'account_number': '5PY28264',
#   'pay_date': '2021-08-31T21:00:00Z',
#   'pay_period_start': '2021-08-31T21:00:00Z',
#   'pay_period_end': '2021-08-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.93',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'e857169a-2f66-4d5b-b3de-419a174b7163',
#   'account_number': '5PY28264',
#   'pay_date': '2021-07-30T21:00:00Z',
#   'pay_period_start': '2021-07-30T21:00:00Z',
#   'pay_period_end': '2021-07-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.58',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '9c77204f-e63d-4fbb-ab93-6704a24be8b2',
#   'account_number': '5PY28264',
#   'pay_date': '2021-06-30T21:00:00Z',
#   'pay_period_start': '2021-06-30T21:00:00Z',
#   'pay_period_end': '2021-06-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.23',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'bf13ac98-e5ca-4c60-992e-e7c5685eab16',
#   'account_number': '5PY28264',
#   'pay_date': '2021-05-28T21:00:00Z',
#   'pay_period_start': '2021-05-28T21:00:00Z',
#   'pay_period_end': '2021-05-28T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.83',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '9fd31602-1937-4839-b7c8-44ae63082901',
#   'account_number': '5PY28264',
#   'pay_date': '2021-04-30T21:00:00Z',
#   'pay_period_start': '2021-04-30T21:00:00Z',
#   'pay_period_end': '2021-04-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '1.03',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'd39cfd63-753f-4391-8718-dc6e47a133c1',
#   'account_number': '5PY28264',
#   'pay_date': '2021-03-31T21:00:00Z',
#   'pay_period_start': '2021-03-31T21:00:00Z',
#   'pay_period_end': '2021-03-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.24',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'd341c24a-34ce-4329-a7d7-7e94bd65a4c5',
#   'account_number': '5PY28264',
#   'pay_date': '2021-02-26T22:00:00Z',
#   'pay_period_start': '2021-02-26T22:00:00Z',
#   'pay_period_end': '2021-02-26T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.42',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'f63d8f90-69af-4bdb-87ec-16048203b1a8',
#   'account_number': '5PY28264',
#   'pay_date': '2021-01-29T22:00:00Z',
#   'pay_period_start': '2021-01-29T22:00:00Z',
#   'pay_period_end': '2021-01-29T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.02',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '4e0c9b4e-0323-464b-a9c3-bea3d5ab922f',
#   'account_number': '5PY28264',
#   'pay_date': '2020-12-31T22:00:00Z',
#   'pay_period_start': '2020-12-31T22:00:00Z',
#   'pay_period_end': '2020-12-31T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.01',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'dabc864b-f676-4fbd-8ec9-d1d45bf74bfd',
#   'account_number': '5PY28264',
#   'pay_date': '2020-11-30T22:00:00Z',
#   'pay_period_start': '2020-11-30T22:00:00Z',
#   'pay_period_end': '2020-11-30T22:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.05',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': '43e730ab-a2e9-4142-b1ba-d4fe9313c7ac',
#   'account_number': '5PY28264',
#   'pay_date': '2020-08-31T21:00:00Z',
#   'pay_period_start': '2020-08-31T21:00:00Z',
#   'pay_period_end': '2020-08-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.05',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'c55bb69b-da00-4069-a03a-3e38235d779d',
#   'account_number': '5PY28264',
#   'pay_date': '2020-07-31T21:00:00Z',
#   'pay_period_start': '2020-07-31T21:00:00Z',
#   'pay_period_end': '2020-07-31T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'},
#  {'amount': {'amount': '0.03',
#    'currency_code': 'USD',
#    'currency_id': '1072fc76-1862-41ab-82c2-485837590762'},
#   'direction': 'credit',
#   'id': 'c11c6b1c-0b51-40de-b358-a71c9ab5d3aa',
#   'account_number': '5PY28264',
#   'pay_date': '2020-06-30T21:00:00Z',
#   'pay_period_start': '2020-06-30T21:00:00Z',
#   'pay_period_end': '2020-06-30T21:00:00Z',
#   'payout_type': 'end_of_month_payment',
#   'reason': 'interest_payment'}]
